# %% [markdown]
# ## Lesson 3
# # Pandas

# %%
# Importing Libraries
import pandas as pd
import numpy as np

# %%
# Basic data table in Pandas

df = pd.DataFrame({
    'A':[1,2,3],
    'B':[4,5,6],
    'C':[7,8,9]
}, index=['x','y','z'])
df.head()
# Out:
#    A  B  C
# x  1  4  7
# y  2  5  8
# z  3  6  9

# %%
# Getting just 2 rows
df.head(2)
# Out:
#    A  B  C
# x  1  4  7
# y  2  5  8

# %%
# Getting from bottom to top
df.tail()
# Out:
#    A  B  C
# x  1  4  7
# y  2  5  8
# z  3  6  9

# %%
# Getting just 2 rows
df.tail(2)
# Out:
#    A  B  C
# y  2  5  8
# z  3  6  9

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 96.0+ bytes

# %%
df.index.tolist()
# Out:
# ['x', 'y', 'z']

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   2.0  5.0  8.0
# std    1.0  1.0  1.0
# min    1.0  4.0  7.0
# 25%    1.5  4.5  7.5
# 50%    2.0  5.0  8.0
# 75%    2.5  5.5  8.5
# max    3.0  6.0  9.0

# %%
df['A'].unique()
# Out:
# array([1, 2, 3])

# %%
df.shape
# Out:
# (3, 3)

# %%
df.size
# Out:
# 9

# %%
# Reading CSV file

coffee = pd.read_csv("./assets/coffee.csv")
coffee.head(4)
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          15
# 2  Tuesday    Espresso          30
# 3  Tuesday       Latte          20

# %%
# Reading Parquet file

results = pd.read_parquet("./assets/results.parquet")
results.head(4)
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None

# %%
bios = pd.read_csv("./assets/bios.csv")
bios.head(4)
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
display(coffee)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# Using loc in Pandas
coffee.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
coffee.loc[3]
# Out:
# Day            Tuesday
# Coffee Type      Latte
# Units Sold          20
# Name: 3, dtype: object

# %%
# Using array in fetching the locs in Pandas

coffee.loc[[0,1,5]]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 5  Wednesday       Latte          25

# %%
# Using range in loc in Pandas

coffee.loc[0:5]
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25

# %%
# Fetching locations but rolling out some columns
coffee.loc[0:5, ["Day", "Units Sold"]]
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35
# 5  Wednesday          25

# %%
# Using iloc to filter columns

coffee.iloc[0:5, [0, 2]]
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %%
# Changing the index

coffee.index = coffee["Day"]
coffee.head(14)
# Out:
#                  Day Coffee Type  Units Sold
# Day
# Monday        Monday    Espresso          25
# Monday        Monday       Latte          15
# Tuesday      Tuesday    Espresso          30
# Tuesday      Tuesday       Latte          20
# Wednesday  Wednesday    Espresso          35
# Wednesday  Wednesday       Latte          25
# Thursday    Thursday    Espresso          40
# Thursday    Thursday       Latte          30
# Friday        Friday    Espresso          45
# Friday        Friday       Latte          35
# Saturday    Saturday    Espresso          45
# Saturday    Saturday       Latte          35
# Sunday        Sunday    Espresso          45
# Sunday        Sunday       Latte          35

# %%
# Filter the amount
coffee = pd.read_csv("./assets/coffee.csv")
coffee.loc[1, 'Units Sold'] = 10
coffee.head(3)
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          10
# 2  Tuesday    Espresso          30

# %%
coffee.loc[1:3, 'Units Sold'] = 10
coffee.head(4)
# Out:
#        Day Coffee Type  Units Sold
# 0   Monday    Espresso          25
# 1   Monday       Latte          10
# 2  Tuesday    Espresso          10
# 3  Tuesday       Latte          10

# %%
# Sorting base on values
coffee.sort_values(["Coffee Type", "Units Sold"])
# Out:
#           Day Coffee Type  Units Sold
# 2     Tuesday    Espresso          10
# 0      Monday    Espresso          25
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35

# %%
# Sorting base on values ascending
coffee.sort_values(["Coffee Type", "Units Sold"], ascending=[0,1])
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          10
# 3     Tuesday       Latte          10
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          10
# 0      Monday    Espresso          25
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
# Extracting data for Python
for index, row in coffee.iterrows():
    print(index, row['Coffee Type'])
# Out:
# 0 Espresso
# 1 Latte
# 2 Espresso
# 3 Latte
# 4 Espresso
# 5 Latte
# 6 Espresso
# 7 Latte
# 8 Espresso
# 9 Latte
# 10 Espresso
# 11 Latte
# 12 Espresso
# 13 Latte

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bios.tail()
# Out:
#         athlete_id                 name   born_date        born_city  \
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
# 145499      149814        Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# 145495       Sverdlovsk          RUS        ROC      167.0       61.0
# 145496           Moskva          RUS        ROC      168.0       65.0
# 145497      Arkhangelsk          RUS        ROC      163.0       55.0
# 145498      Deux-Sèvres          FRA     France      166.0        NaN
# 145499  New South Wales          AUS  Australia        NaN        NaN
#
#          died_date
# 145495         NaN
# 145496         NaN
# 145497         NaN
# 145498  1986-03-18
# 145499  2003-10-20

# %%
bios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
# Fetching the athlete born in Malaysia

bios.loc[(bios['born_country']=="MAS")]
# Out:
#         athlete_id                        name   born_date         born_city  \
# 950            954              Cheah Soon Kit  1968-01-09              Ipoh
# 952            956                Ong Ewe Hock  1972-03-14            Penang
# 953            957          Alan Sidek Mohamed  1963-11-10           Banting
# 954            958          Ajib Sidek Mohamed  1968-07-08           Banting
# 958            962                Yap Kim Hock  1970-07-02              Muar
# ...            ...                         ...         ...               ...
# 132242      135093                  Welson Sim  1997-03-29           Kuching
# 132243      135094  Mohammad Hafifi bin Mansor  1990-10-28  Kuala Terengganu
# 134593      137673                Jeffrey Webb  1998-10-27      Kuala Lumpur
# 134594      137674                  Julian Yee  1997-05-26      Kuala Lumpur
# 135271      138434                P. Alagendra  1929-07-23            Kajang
#
# ...

# %%
bios[bios['name'].str.contains('Julian', case=False)]
# Out:
#         athlete_id              name   born_date     born_city  \
# 113            114  Julian Robertson  1969-10-09  Peterborough
# 7404          7444      Julian Rossi  1942-02-12           NaN
# 8753          8800    Julian Wheeler  1971-04-22     Lafayette
# 14021        14112       Julian Dean  1975-01-28         Waihi
# 17442        17562     Julian Pearce  1937-04-15      Jabalpur
# ...            ...               ...         ...           ...
# 143786      147442   Julian Venonsky  1993-10-15           NaN
# 144191      147872    Julian Lüftner  1993-01-11          Zams
# 144549      148241   Julian Jakobsen  1987-04-11       Aalborg
# 144732      148432     Julian Schmid  1999-09-01    Oberstdorf
# 145453      149178  Julian Rauchfuss  1994-09-02    Mindelheim
#
#            born_region born_country            NOC  height_cm  weight_kg  \
# 113            England          GBR  Great Britain      182.0       73.0
# ...

# %%
bios.query('born_country=="MAS" and born_city=="Kuala Lumpur"')
# Out:
#         athlete_id                        name   born_date     born_city  \
# 11239        11298               Diana Clapham  1957-06-08  Kuala Lumpur
# 13291        13372                 Rosman Alwi  1961-12-05  Kuala Lumpur
# 15743        15853                 Ng Joo Pong  1946-06-19  Kuala Lumpur
# 17430        17550                  Don Martin  1940-02-08  Kuala Lumpur
# 19421        19560             Chuah Eng Cheng  1921-01-01  Kuala Lumpur
# 19431        19570            Avtar Singh Gill  1954-12-29  Kuala Lumpur
# 19452        19591             Thomas Lawrence  1929-01-01  Kuala Lumpur
# 19456        19595    Maninderjit Singh Magmar  1972-11-17  Kuala Lumpur
# 19464        19603            Supaat Nadarajah  1920-01-01  Kuala Lumpur
# 25074        25264          Frederick Nicholas  1893-07-25  Kuala Lumpur
# 33828        34091           Kanapathy Moorthy  1932-12-23  Kuala Lumpur
# 42951        43276              Chan Kooi Chye  1921-06-20  Kuala Lumpur
# ...

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          10
# 2    Tuesday    Espresso          10
# 3    Tuesday       Latte          10
# 4  Wednesday    Espresso          35

# %%
coffee['Price'] = 25
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price
# 0     Monday    Espresso          25     25
# 1     Monday       Latte          10     25
# 2    Tuesday    Espresso          10     25
# 3    Tuesday       Latte          10     25
# 4  Wednesday    Espresso          35     25

# %%
coffee['New Price'] = np.where(coffee['Coffee Type']=='Espresso', 30, 35)
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  Price  New Price
# 0     Monday    Espresso          25     25         30
# 1     Monday       Latte          10     25         35
# 2    Tuesday    Espresso          10     25         30
# 3    Tuesday       Latte          10     25         35
# 4  Wednesday    Espresso          35     25         30

# %%
coffee.drop(columns=['Price'], inplace=True)
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  New Price
# 0     Monday    Espresso          25         30
# 1     Monday       Latte          10         35
# 2    Tuesday    Espresso          10         30
# 3    Tuesday       Latte          10         35
# 4  Wednesday    Espresso          35         30

# %%
# Copying in Pandas
coffee_new = coffee.copy()
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  New Price
# 0     Monday    Espresso          25         30
# 1     Monday       Latte          10         35
# 2    Tuesday    Espresso          10         30
# 3    Tuesday       Latte          10         35
# 4  Wednesday    Espresso          35         30

# %%
# Doing Arithmetic equation in columns

coffee_new['Revenue']=coffee_new['Units Sold']*coffee_new['New Price']
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  New Price  Revenue
# 0     Monday    Espresso          25         30      750
# 1     Monday       Latte          10         35      350
# 2    Tuesday    Espresso          10         30      300
# 3    Tuesday       Latte          10         35      350
# 4  Wednesday    Espresso          35         30     1050

# %%
# Renaming the headers
coffee_new.rename(columns={"New Price":"Price"}, inplace=True)
coffee_new.head()
# Out:
#          Day Coffee Type  Units Sold  Price  Revenue
# 0     Monday    Espresso          25     30      750
# 1     Monday       Latte          10     35      350
# 2    Tuesday    Espresso          10     30      300
# 3    Tuesday       Latte          10     35      350
# 4  Wednesday    Espresso          35     30     1050

# %%
bios.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bn = bios.copy()
bn.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
bn['First Name']=bn['name'].str.split(' ').str[0]
bn.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     First Name
# 0  1960-10-02  Jean-François
# 1         NaN         Arnaud
# 2  1994-07-17           Jean
# 3  1978-03-20        Jacques
# 4  1930-07-25         Albert

# %%
bn.drop(columns=['First Name'], inplace=True)
bn['first_name']=bn['name'].str.split(' ').str[0]
bn.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name
# 0  1960-10-02  Jean-François
# 1         NaN         Arnaud
# 2  1994-07-17           Jean
# 3  1978-03-20        Jacques
# 4  1930-07-25         Albert

# %%
bn.query('first_name == "Julian"')
# Out:
#         athlete_id                    name   born_date  \
# 113            114        Julian Robertson  1969-10-09
# 7404          7444            Julian Rossi  1942-02-12
# 8753          8800          Julian Wheeler  1971-04-22
# 14021        14112             Julian Dean  1975-01-28
# 17442        17562           Julian Pearce  1937-04-15
# 17666        17787           Julian Austin  1949-12-30
# 18652        18780            Julian Halls  1967-04-17
# 31190        31426          Julian Schmitz  1881-09-15
# 33383        33637           Julian Davies  1971-03-16
# 44832        45174          Julian Carroll  1942-11-05
# 49753        50111          Julian Bolling  1966-06-19
# 53044        53419         Julian Muspratt  1958-08-26
# 55324        55719            Julian Creus  1917-06-30
# 61019        61461  Julian Brooke-Houghton  1946-12-16
# 63023        63493        Julian Roosevelt  1924-11-14
# 64287        64769          Julian Paynter  1970-07-15
# ...

# %%
bn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  first_name    145500 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 12.2+ MB

# %%
# Converting the Object to Date and Time
bn['born_date'] = pd.to_datetime(bn['born_date'])
bn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  datetime64[ns]
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
#  10  first_name    145500 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(7)
# memory usage: 12.2+ MB

# %%
# Taking out the year of birth
bn['born_year'] = bn['born_date'].dt.year
bn.head()
# Out:
#    athlete_id                   name  born_date    born_city  \
# 0           1  Jean-François Blanchy 1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch 1969-04-01       Meulan
# 2           3           Jean Borotra 1898-08-13     Biarritz
# 3           4        Jacques Brugnon 1895-05-11  Paris VIIIe
# 4           5           Albert Canet 1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date     first_name  born_year
# 0  1960-10-02  Jean-François     1886.0
# 1         NaN         Arnaud     1969.0
# 2  1994-07-17           Jean     1898.0
# ...

# %%
bn[['first_name', 'born_year']].head(4)
# Out:
#       first_name  born_year
# 0  Jean-François     1886.0
# 1         Arnaud     1969.0
# 2           Jean     1898.0
# 3        Jacques     1895.0

# %%
bn.to_csv('./assets/bn.csv', index=False)

# %%
bh = bios.copy()
bh.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
# Doing if and else statement to fetch data in Pandas using Lambda

bh['height_cat'] = bh['height_cm'].apply(lambda x:"Short" if x <170 else 'Tall')
bh[['name', 'height_cm', 'height_cat', 'weight_kg']].head()
# Out:
#                     name  height_cm height_cat  weight_kg
# 0  Jean-François Blanchy        NaN       Tall        NaN
# 1         Arnaud Boetsch      183.0       Tall       76.0
# 2           Jean Borotra      183.0       Tall       76.0
# 3        Jacques Brugnon      168.0      Short       64.0
# 4           Albert Canet        NaN       Tall        NaN

# %%
# Doing if and else statement to fetch data in Pandas using def

def hw_category(row):
    if row['height_cm'] < 170 and row['weight_kg']>60:
        return "Short and Chubby"
    elif row['height_cm'] < 170 and row['weight_kg']<60:
        return "Short and Skinny"
    elif row['height_cm'] > 170 and row['weight_kg']<72:
        return "Tall and Skinny"
    elif row['height_cm'] > 170 and row['weight_kg']>72:
        return "Tall and Chubby"
    else:
        return "Abnormal"

bhw = bios.copy()
bhw['category'] = bhw.apply(hw_category, axis=1)
bhw[['name', 'height_cm', 'weight_kg', 'category']].head(10)
# Out:
#                     name  height_cm  weight_kg          category
# 0  Jean-François Blanchy        NaN        NaN          Abnormal
# 1         Arnaud Boetsch      183.0       76.0   Tall and Chubby
# 2           Jean Borotra      183.0       76.0   Tall and Chubby
# 3        Jacques Brugnon      168.0       64.0  Short and Chubby
# 4           Albert Canet        NaN        NaN          Abnormal
# 5      Nicolas Chatelain      181.0       70.0   Tall and Skinny
# 6          Patrick Chila      180.0       73.0   Tall and Chubby
# 7           Henri Cochet        NaN        NaN          Abnormal
# 8          Marcel Cousin        NaN        NaN          Abnormal
# 9     Guy de la Chapelle        NaN        NaN          Abnormal
